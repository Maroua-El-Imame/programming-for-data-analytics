# %% [markdown]
# Look at this file ([There is a copy of it on github](https://github.com/andrewbeattycourseware/PFDA-courseware/blob/main/code/data/projectedbirths-cso.csv)) I have taken from the CSO, it is a the projected birth-rates in Ireland. Write a Jupyter notebook that displays a plot of this projected birth-rates.
#
# There is also a file with the number of people by age, make a plot that you think is interesting from this data
